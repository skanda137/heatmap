# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from fredapi import fred
#downloaded all the dependencies

# %%
msft = yf.Ticker("MSFT")
#print(msft.financials)
#print(msft.balance_sheet)
print(msft.info['regularMarketPrice'])
#this is an example of how yfinance tickers are used, I used the ticker for microsoft right now
#The regular market price shows us the price at that moment as yfinance is a live stat unlike kaggle datasets which are offline datasets

# %%
data = yf.download(tickers=["MSFT", "TSLA", "AAPL"], start="2024-02-09", end="2026-02-09", interval="1d")   
#I loaded the data from Microsoft, Tesla & Apple for this project from start date of 9th feb 2024 to 9th feb 2026 spanning over 2 years
#Since yahoo has many columns such as open, high, close, low and so on - we extract only those columns needed for us
#For example - I'll plot the close prices of all 3 stocks over this time period
data["Close"].plot(title="Close prices")
plt.show()

# %%
#Now lets convert all of these datasets to excel using the to_excel function provided by pandas
msft_balance_sheet = msft.balance_sheet
msft_balance_sheet.to_excel("MSFT_balance.xlsx")

aapl = yf.Ticker("AAPL")
aapl_div = aapl.dividends
aapl_div.index = aapl.dividends.index.tz_localize(None)
aapl_div.to_excel("AAPL_dividends.xlsx")
#We have to use the localize function because excel does not support datetime format with different timezones

# %%
#As it is a live site, we do not need to check and clean up missing or irrelevant data - else we would have to do the following
#data.isnull().sum() to check if any column has null values while missing values would have isna() function
#We will use kaggle datasets in the future to show how this works
#Now let us plot the highs for the data just to understand the dataset and work on plotting graphs

# %%
high_data = data.xs('High', axis=1, level=0)
plt.figure(figsize=(20, 10))
#This is to initialize a new figure, set its colour and size and loop over the tickers
for ticker in high_data.columns:
    sns.lineplot(
        data=high_data[ticker],  
        label=ticker,
        linewidth=3
    )

plt.title('High Trends')
plt.xlabel('Date')   
plt.ylabel('Volume')  
plt.show()

# %%
#Now we have an idea of how yfinance works and how pandas works with it
#We move on to forming the correlation heatmap
#Using stocks of microsoft,apple and tesla will not give us any distribution in the correlation heatmap as they all revolve 
#around the same factors - this defies the purpose of the project.
#Hence, we use equity indices such as S&P500, Euro Stoxx and others instead in the next file
